# %%
from skimage.io import imread, imshow, imsave

# %%
# %matplotlib inline

# %%
imshow('me.jpg')

# %%
# %matplotlib inline

# %%
from skimage.io import imreadim, imshow, imsave
import numpy
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-399f134135b5> in <module>
# ----> 1 from skimage.io import imreadim, imshow, imsave
#       2 import numpy
#
# ImportError: cannot import name 'imreadim' from 'skimage.io' (/Users/georgiiivannikov/miniconda3/lib/python3.7/site-packages/skimage/io/__init__.py)

# %%
img = imread('me.jpg')
imshow(img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-ece0250d5558> in <module>
# ----> 1 img = imread('me.jpg')
#       2 imshow(img)
#
# NameError: name 'imread' is not defined

# %%
from skimage.io import imreadim, imshow, imsave
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-62eb45157b2b> in <module>
# ----> 1 from skimage.io import imreadim, imshow, imsave
#
# ImportError: cannot import name 'imreadim' from 'skimage.io' (/Users/georgiiivannikov/miniconda3/lib/python3.7/site-packages/skimage/io/__init__.py)

# %%
from skimage.io import imread, imshow, imsave

# %%
img = imread('me.jpg')
imshow(img)

# %%
img = imread('https://stepik.org/media/attachments/lesson/58180/tiger-border.png')
imshow(img)

# %%
img.size
# Out:
# 1600788

# %%
img[0][0]
# Out:
# Array([ 81, 243, 165], dtype=uint8)

# %%
img.shape
# Out:
# (646, 826, 3)

# %%
def border(img):
    border = [0, 0, 0, 0] #left, right, top, left

    heigth = img.shape[0]
    width = img.shape[1]

    border_color = img[0][0]

    for i in range(heigth):
        for j in range (width):
            if not np.array_equal(img[i,j], border_color):
                top = heigth - 1 - i
                left = width - 1 - j
    
    for k in reversed(range(heigth)):
        for l in reversed(range(width)):
            if not np.array_equal(img[k,l], border_color):
                bottom = k
                right = l
                

    print(left, right, top, bottom)

# %%
import numpy as np

# %%
border(img)
# Out:
# 25 1 7 39
